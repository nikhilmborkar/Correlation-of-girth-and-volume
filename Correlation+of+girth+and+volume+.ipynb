# %%
#R has a nice data set on some physical characteristics of Black Cherry Trees. While most of us 
#think about girth as the distance around
#something, here we find a simple scaling being used.
#This data set provides measurements of the girth, height and volume of timber in 31 felled black cherry trees. 
#Note that girth is the diameter of the tree (in inches) measured at 4 ft 6 
#in above the ground.

# %%
pairs(trees, pch = 21, bg = c("red"))
# Out:
# plot without title

# %%
#It appears that our variables are all positively correlated, as we’d expect. 
#The linear relationship between Girth and Volume seems especially strong.
#We wouldn’t have come to that conclusion only looking at the covariances!
